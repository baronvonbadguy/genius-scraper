# %%
import requests as rq
from lxml import html

def xpath_query_url(url, xpath_query, payload=dict(), params=dict()):
    '''Gets url and performs an XPath Query'''
    headers = {'User-Agent': 'Mozilla/5.0 Gecko/20100101 Firefox/35.0'}
    if payload:
        headers.update(payload)
    try:
        response = rq.get(url, headers=headers, params=params)
        #creates an html tree from the data
        tree = html.fromstring(response.text)
        #XPATH query to grab all of the artist urls, then we grab the first
        return tree.xpath(xpath_query)
    except Exception as e:
        print(e)
        return ''

# %%
from re import sub
def fetch_artist_names(random_sample=None):
    '''Fetches top artists from wikipedia'''
    base = 'https://en.wikipedia.org/wiki/List_of_hip_hop_musicians'
    query = '//li/a/@title'
    results = xpath_query_url(base, query)

    if results:
        results = [sub(' \([\w ]+\)', '', a) for a in results]

    return results

wiki_artists = fetch_artist_names()
wiki_artists += ['2Pac', 'Joey BADA$$']
wiki_artist_count = len(wiki_artists)
print('Scraped {} potential artists'.format(wiki_artist_count))
# Out:
# Scraped 1176 potential artists

# %%
import gevent
from gevent.pool import Pool
from gevent import monkey
from functools import partial
import signal

gevent.monkey.patch_all(thread=False)
gevent.signal(signal.SIGQUIT, gevent.kill)

def grab_artist_links(artist):
    base = 'http://genius.com/search/artists'
    params = {'q': artist}
    xpath = '//li/a[@class="artist_link"]/@href'
    artist_links = partial(xpath_query_url, 
                           xpath_query=xpath, 
                           url=base)
    return artist, artist_links(params=params)

artist_link_lists = Pool(100).map(grab_artist_links, wiki_artists)
# filters out artists we couldn't find links for
# as well as false positives that aren't even artists 
artist_link_lists = [alist for alist in artist_link_lists if alist[1]]
# grabs just the first link from each list
artist_link_lists = [(alist[0], alist[1][0]) for alist in artist_link_lists if alist[1]]

# %%
def grab_artist_id(args):
    artist, artist_url = args
    xpath = '//meta[@name="newrelic-resource-path"]/@content'
    artist_id_raw = xpath_query_url(artist_url, xpath)
    
    if artist_id_raw:
        delisted = artist_id_raw[0]
        if delisted and 'artists/' in delisted:
            artist_id = delisted.split('artists/')[1]
            return artist, artist_id
    return artist, None

artist_ids = Pool(100).map(grab_artist_id, artist_link_lists)
# filters out missing entries that couldn't be resolved
artist_ids_filtered = [a for a in artist_ids if all(a)]

filtered_artist_count = len(artist_ids_filtered)
artist_count_diff = wiki_artist_count - filtered_artist_count
feedback = 'Found {} artist_ids, filtered out {} negative results'
print(feedback.format(filtered_artist_count, artist_count_diff))
# Out:
# Found 1108 artist_ids, filtered out 68 negative results

# %%
class Genius:
    def __init__(self):
        token = 'nmovpnwjelwjWJG_jjQHu-Emfhsv0WX0iv_WZxz5LRpzjjAezDXMhW56jhzwC634'
        headers = {'Authorization': 'Bearer {}'.format(token)}
        self._sesh = rq.Session()
        self._sesh.headers.update(headers)
        self._base = 'http://api.genius.com'
        
    def _key_response(self, response, subkey):
        r = response.get('response', None)
        if r and subkey in r:
            return r[subkey]
        return {}

    def get_artist(self, artist_id):
        url = '{}/artists/{}'.format(self._base, artist_id)
        response = self._sesh.get(url, params={'text_format': 'plain'}).json()
        return self._key_response(response, 'artist')
    
    def get_artist_songs(self, artist_id, page, sort='title', per_page=50):
        url = '{}/artists/{}/songs'.format(self._base, artist_id)
        params = {'sort': sort, 'per_page': per_page, 'page': page}
        response = self._sesh.get(url, params=params).json()
        return response.get('response', None)
    
    def get_song(self, song_id):
        url = '{}/songs/{}'.format(self._base, song_id)
        response = self._sesh.get(url, params={'text_format': 'plain'}).json()
        return self._key_response(response, 'song')

# %%
api = Genius()
api.get_artist_songs(28906, 1)
# Out:
# {'next_page': 2,
#  'songs': [{'annotation_count': 11,
#    'api_path': '/songs/716144',
#    'full_title': 'Adore by\xa0Cashmere\xa0Cat (Ft.\xa0Ariana\xa0Grande)',
#    'header_image_thumbnail_url': 'https://images.genius.com/e7cd910c669142c161e494dae0c161fe.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/e7cd910c669142c161e494dae0c161fe.1000x1000x1.png',
#    'id': 716144,
#    'lyrics_owner_id': 104344,
#    'path': '/Cashmere-cat-adore-lyrics',
#    'primary_artist': {'api_path': '/artists/49698',
#     'header_image_url': 'https://images.genius.com/30a2628f1de2b58dccd193e87f051415.1000x668x1.jpg',
#     'id': 49698,
#     'image_url': 'https://images.genius.com/36a655defd25e908cc0cba4aa197db24.1000x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Cashmere Cat',
#     'url': 'http://genius.com/artists/Cashmere-cat'},
#    'pyongs_count': 33,
#    'stats': {'hot': False, 'pageviews': 22401, 'unreviewed_annotations': 0},
#    'title': 'Adore',
#    'url': 'http://genius.com/Cashmere-cat-adore-lyrics'},
#   {'annotation_count': 13,
#    'api_path': '/songs/2458387',
#    'full_title': 'All In My Head (Flex) by\xa0Fifth\xa0Harmony (Ft.\xa0Fetty\xa0Wap)',
#    'header_image_thumbnail_url': 'https://images.genius.com/5e08fd70df006b182cbd33d6fd045041.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/5e08fd70df006b182cbd33d6fd045041.1000x1000x1.jpg',
#    'id': 2458387,
#    'lyrics_owner_id': 2184014,
#    'path': '/Fifth-harmony-all-in-my-head-flex-lyrics',
#    'primary_artist': {'api_path': '/artists/60437',
#     'header_image_url': 'https://images.genius.com/fa7de7ab884bfe8644aa9c8e3d2332ef.600x409x1.png',
#     'id': 60437,
#     'image_url': 'https://images.genius.com/9066c82a9a5170f8f91ab94a637f2b9f.1000x1000x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Fifth Harmony',
#     'url': 'http://genius.com/artists/Fifth-harmony'},
#    'pyongs_count': 8,
#    'stats': {'concurrents': 4,
#     'hot': False,
#     'pageviews': 107531,
#     'unreviewed_annotations': 3},
#    'title': 'All In My Head (Flex)',
#    'url': 'http://genius.com/Fifth-harmony-all-in-my-head-flex-lyrics'},
#   {'annotation_count': 2,
#    'api_path': '/songs/2848612',
#    'full_title': 'All In My Head (Flex) (DJ Keynote Speakaz Will Take You There Remix) by\xa0Pete\xa0Rock & C.L. Smooth (Ft.\xa0Dinah\xa0Jane Hansen, Lauren\xa0Jauregui & Normani\xa0Kordei)',
#    'header_image_thumbnail_url': 'https://images.genius.com/214ef6663d4ebb8984a64987794596f4.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/214ef6663d4ebb8984a64987794596f4.1000x1000x1.jpg',
#    'id': 2848612,
#    'lyrics_owner_id': 3667740,
#    'path': '/Pete-rock-and-cl-smooth-all-in-my-head-flex-dj-keynote-speakaz-will-take-you-there-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/1125',
#     'header_image_url': 'https://images.genius.com/58ctdxwubm8hjqiicqdkvw0aj.753x1000x1.jpg',
#     'id': 1125,
#     'image_url': 'https://images.genius.com/58ctdxwubm8hjqiicqdkvw0aj.753x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Pete Rock & C.L. Smooth',
#     'url': 'http://genius.com/artists/Pete-rock-and-cl-smooth'},
#    'pyongs_count': 2,
#    'stats': {'hot': False, 'unreviewed_annotations': 2},
#    'title': 'All In My Head (Flex) (DJ Keynote Speakaz Will Take You There Remix)',
#    'url': 'http://genius.com/Pete-rock-and-cl-smooth-all-in-my-head-flex-dj-keynote-speakaz-will-take-you-there-remix-lyrics'},
#   {'annotation_count': 6,
#    'api_path': '/songs/2848552',
#    'full_title': 'All In My Head (Flex) [Solo Version] by\xa0Fifth\xa0Harmony',
#    'header_image_thumbnail_url': 'https://images.genius.com/1be68bba0bebe790a19f241ad63ffd4d.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/1be68bba0bebe790a19f241ad63ffd4d.600x600x1.jpg',
#    'id': 2848552,
#    'lyrics_owner_id': 2813390,
#    'path': '/Fifth-harmony-all-in-my-head-flex-solo-version-lyrics',
#    'primary_artist': {'api_path': '/artists/60437',
#     'header_image_url': 'https://images.genius.com/fa7de7ab884bfe8644aa9c8e3d2332ef.600x409x1.png',
#     'id': 60437,
#     'image_url': 'https://images.genius.com/9066c82a9a5170f8f91ab94a637f2b9f.1000x1000x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Fifth Harmony',
#     'url': 'http://genius.com/artists/Fifth-harmony'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 6},
#    'title': 'All In My Head (Flex) [Solo Version]',
#    'url': 'http://genius.com/Fifth-harmony-all-in-my-head-flex-solo-version-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/856289',
#    'full_title': "Amazed by\xa0Vanessa\xa0Hudgens (Ft.\xa0Lil'\xa0Mama)",
#    'header_image_thumbnail_url': 'https://images.genius.com/f96a67ea0e87856316103f253478fb6b.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/f96a67ea0e87856316103f253478fb6b.600x600x1.jpg',
#    'id': 856289,
#    'lyrics_owner_id': 1549345,
#    'path': '/Vanessa-hudgens-amazed-lyrics',
#    'primary_artist': {'api_path': '/artists/184931',
#     'header_image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'id': 184931,
#     'image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Vanessa Hudgens',
#     'url': 'http://genius.com/artists/Vanessa-hudgens'},
#    'pyongs_count': 1,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Amazed',
#    'url': 'http://genius.com/Vanessa-hudgens-amazed-lyrics'},
#   {'annotation_count': 19,
#    'api_path': '/songs/502834',
#    'full_title': 'Animals by\xa0Maroon\xa05',
#    'header_image_thumbnail_url': 'https://images.genius.com/571717bdf1b6bb7a1c3a9a497edb235b.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/571717bdf1b6bb7a1c3a9a497edb235b.1000x1000x1.png',
#    'id': 502834,
#    'lyrics_owner_id': 1046922,
#    'path': '/Maroon-5-animals-lyrics',
#    'primary_artist': {'api_path': '/artists/13539',
#     'header_image_url': 'https://images.genius.com/6b1507687e6b85724d05c46874d88c18.1000x563x1.jpg',
#     'id': 13539,
#     'image_url': 'https://images.genius.com/6b1507687e6b85724d05c46874d88c18.1000x563x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Maroon 5',
#     'url': 'http://genius.com/artists/Maroon-5'},
#    'pyongs_count': 116,
#    'stats': {'hot': False, 'pageviews': 69667, 'unreviewed_annotations': 9},
#    'title': 'Animals',
#    'url': 'http://genius.com/Maroon-5-animals-lyrics'},
#   {'annotation_count': 4,
#    'api_path': '/songs/483748',
#    'full_title': 'Appreciated by\xa0Rixton',
#    'header_image_thumbnail_url': 'https://images.genius.com/35bd97138f1e737653165e5de8c7fdbe.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/35bd97138f1e737653165e5de8c7fdbe.1000x1000x1.jpg',
#    'id': 483748,
#    'lyrics_owner_id': 929713,
#    'path': '/Rixton-appreciated-lyrics',
#    'primary_artist': {'api_path': '/artists/162095',
#     'header_image_url': 'https://images.genius.com/64236cda88ee55db5fe83bd2f77feabf.670x339x1.jpg',
#     'id': 162095,
#     'image_url': 'https://images.genius.com/64236cda88ee55db5fe83bd2f77feabf.670x339x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Rixton',
#     'url': 'http://genius.com/artists/Rixton'},
#    'pyongs_count': 13,
#    'stats': {'hot': False, 'unreviewed_annotations': 4},
#    'title': 'Appreciated',
#    'url': 'http://genius.com/Rixton-appreciated-lyrics'},
#   {'annotation_count': 8,
#    'api_path': '/songs/520237',
#    'full_title': "Baby Don't Lie by\xa0Gwen\xa0Stefani",
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/13f891c603ac2ca7c13d5b832762c42c.300x300x1.png',
#    'header_image_url': 'https://images.rapgenius.com/13f891c603ac2ca7c13d5b832762c42c.1000x1000x1.png',
#    'id': 520237,
#    'lyrics_owner_id': 554585,
#    'path': '/Gwen-stefani-baby-dont-lie-lyrics',
#    'primary_artist': {'api_path': '/artists/1893',
#     'header_image_url': 'https://images.genius.com/9eeac98d4853152df2a319ce79b7cba2.800x800x1.jpg',
#     'id': 1893,
#     'image_url': 'https://images.genius.com/9eeac98d4853152df2a319ce79b7cba2.800x800x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Gwen Stefani',
#     'url': 'http://genius.com/artists/Gwen-stefani'},
#    'pyongs_count': 24,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': "Baby Don't Lie",
#    'url': 'http://genius.com/Gwen-stefani-baby-dont-lie-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/1655986',
#    'full_title': 'Bad Dog by\xa0Neon\xa0Hitch',
#    'header_image_thumbnail_url': 'https://images.genius.com/746793217023304a6620ac95b4731c9a.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/746793217023304a6620ac95b4731c9a.1000x1000x1.png',
#    'id': 1655986,
#    'lyrics_owner_id': 1549345,
#    'path': '/Neon-hitch-bad-dog-lyrics',
#    'primary_artist': {'api_path': '/artists/15089',
#     'header_image_url': 'https://images.genius.com/867e71fac211863b932a9f2511b6c973.438x438x1.jpg',
#     'id': 15089,
#     'image_url': 'https://images.genius.com/867e71fac211863b932a9f2511b6c973.438x438x1.jpg',
#     'iq': 151,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': 'Neon Hitch',
#     'url': 'http://genius.com/artists/Neon-hitch'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Bad Dog',
#    'url': 'http://genius.com/Neon-hitch-bad-dog-lyrics'},
#   {'annotation_count': 0,
#    'api_path': '/songs/2850437',
#    'full_title': 'Beat x Beat: Ariana Grande “Why Try" by\xa0Ariana\xa0Grande',
#    'header_image_thumbnail_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.300x301x1.jpg',
#    'header_image_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.455x456x1.jpg',
#    'id': 2850437,
#    'lyrics_owner_id': 1666391,
#    'path': '/Ariana-grande-beat-x-beat-ariana-grande-why-try-annotated',
#    'primary_artist': {'api_path': '/artists/26507',
#     'header_image_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.455x456x1.jpg',
#     'id': 26507,
#     'image_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.455x456x1.jpg',
#     'iq': 1082,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Ariana Grande',
#     'url': 'http://genius.com/artists/Ariana-grande'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Beat x Beat: Ariana Grande “Why Try"',
#    'url': 'http://genius.com/Ariana-grande-beat-x-beat-ariana-grande-why-try-annotated'},
#   {'annotation_count': 13,
#    'api_path': '/songs/487490',
#    'full_title': 'Be My Baby by\xa0Ariana\xa0Grande (Ft.\xa0Cashmere\xa0Cat)',
#    'header_image_thumbnail_url': 'https://images.genius.com/ba74d62b3e42d565e4ce87bd4f56483b.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/ba74d62b3e42d565e4ce87bd4f56483b.1000x1000x1.jpg',
#    'id': 487490,
#    'lyrics_owner_id': 1123779,
#    'path': '/Ariana-grande-be-my-baby-lyrics',
#    'primary_artist': {'api_path': '/artists/26507',
#     'header_image_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.455x456x1.jpg',
#     'id': 26507,
#     'image_url': 'https://images.genius.com/c26b2afd813e51fdc53127513c60f970.455x456x1.jpg',
#     'iq': 1082,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Ariana Grande',
#     'url': 'http://genius.com/artists/Ariana-grande'},
#    'pyongs_count': 42,
#    'stats': {'hot': False, 'pageviews': 31033, 'unreviewed_annotations': 0},
#    'title': 'Be My Baby',
#    'url': 'http://genius.com/Ariana-grande-be-my-baby-lyrics'},
#   {'annotation_count': 22,
#    'api_path': '/songs/406511',
#    'full_title': 'Black Widow by\xa0Iggy\xa0Azalea (Ft.\xa0Rita\xa0Ora)',
#    'header_image_thumbnail_url': 'https://images.genius.com/610ee46200e31103db8c40759f5e4abb.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/610ee46200e31103db8c40759f5e4abb.1000x1000x1.png',
#    'id': 406511,
#    'lyrics_owner_id': 653640,
#    'path': '/Iggy-azalea-black-widow-lyrics',
#    'primary_artist': {'api_path': '/artists/14598',
#     'header_image_url': 'https://images.genius.com/6ba1818a5dbc890c393379dd433be2c6.1000x468x1.jpg',
#     'id': 14598,
#     'image_url': 'https://images.genius.com/8686a7330bb1a0ea53176e24587433f7.448x449x1.png',
#     'iq': 100,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Iggy Azalea',
#     'url': 'http://genius.com/artists/Iggy-azalea'},
#    'pyongs_count': 279,
#    'stats': {'hot': False, 'pageviews': 235241, 'unreviewed_annotations': 0},
#    'title': 'Black Widow',
#    'url': 'http://genius.com/Iggy-azalea-black-widow-lyrics'},
#   {'annotation_count': 25,
#    'api_path': '/songs/25977',
#    'full_title': 'Blah Blah Blah by\xa0Kesha (Ft.\xa03OH!3)',
#    'header_image_thumbnail_url': 'https://images.genius.com/0b20d9edd7569ae78b909768f82da7a8.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/0b20d9edd7569ae78b909768f82da7a8.1000x1000x1.jpg',
#    'id': 25977,
#    'lyrics_owner_id': 50,
#    'path': '/Kesha-blah-blah-blah-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 12,
#    'stats': {'hot': False, 'pageviews': 5668, 'unreviewed_annotations': 22},
#    'title': 'Blah Blah Blah',
#    'url': 'http://genius.com/Kesha-blah-blah-blah-lyrics'},
#   {'annotation_count': 11,
#    'api_path': '/songs/25978',
#    'full_title': 'Blind by\xa0Kesha',
#    'header_image_thumbnail_url': 'https://images.genius.com/d72a6ba54d784cb5b0b87f1ccd455769.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d72a6ba54d784cb5b0b87f1ccd455769.600x600x1.jpg',
#    'id': 25978,
#    'lyrics_owner_id': 50,
#    'path': '/Kesha-blind-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 7},
#    'title': 'Blind',
#    'url': 'http://genius.com/Kesha-blind-lyrics'},
#   {'annotation_count': 13,
#    'api_path': '/songs/25986',
#    'full_title': 'Blow by\xa0Kesha',
#    'header_image_thumbnail_url': 'https://images.genius.com/d7676240ce771a0863dafcd1f04f4b32.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d7676240ce771a0863dafcd1f04f4b32.600x600x1.jpg',
#    'id': 25986,
#    'lyrics_owner_id': 50,
#    'path': '/Kesha-blow-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 8,
#    'stats': {'hot': False, 'unreviewed_annotations': 2},
#    'title': 'Blow',
#    'url': 'http://genius.com/Kesha-blow-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/1967335',
#    'full_title': 'B-O-O-T-A-Y by\xa0Benny\xa0Blanco',
#    'header_image_thumbnail_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.300x194x1.jpg',
#    'header_image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#    'id': 1967335,
#    'lyrics_owner_id': 1549345,
#    'path': '/Benny-blanco-b-o-o-t-a-y-lyrics',
#    'primary_artist': {'api_path': '/artists/28906',
#     'header_image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#     'id': 28906,
#     'image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Benny Blanco',
#     'url': 'http://genius.com/artists/Benny-blanco'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'B-O-O-T-A-Y',
#    'url': 'http://genius.com/Benny-blanco-b-o-o-t-a-y-lyrics'},
#   {'annotation_count': 29,
#    'api_path': '/songs/3250',
#    'full_title': 'California Gurls by\xa0Katy\xa0Perry (Ft.\xa0Snoop\xa0Dogg)',
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/c4de10fee83d691284eab28b2528b76b.300x300x1.jpg',
#    'header_image_url': 'https://images.rapgenius.com/c4de10fee83d691284eab28b2528b76b.1000x1000x1.jpg',
#    'id': 3250,
#    'lyrics_owner_id': 7,
#    'path': '/Katy-perry-california-gurls-lyrics',
#    'primary_artist': {'api_path': '/artists/1195',
#     'header_image_url': 'https://images.genius.com/b24lvmn5zyaveb8yivwbyx5i8.628x356x1.jpg',
#     'id': 1195,
#     'image_url': 'https://images.genius.com/b24lvmn5zyaveb8yivwbyx5i8.628x356x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Katy Perry',
#     'url': 'http://genius.com/artists/Katy-perry'},
#    'pyongs_count': 19,
#    'stats': {'hot': False, 'pageviews': 44777, 'unreviewed_annotations': 4},
#    'title': 'California Gurls',
#    'url': 'http://genius.com/Katy-perry-california-gurls-lyrics'},
#   {'annotation_count': 8,
#    'api_path': '/songs/295423',
#    'full_title': 'Cannonball by\xa0Lea\xa0Michele',
#    'header_image_thumbnail_url': 'https://images.genius.com/13ae3047f2024a78b3cdda7d1b1389d9.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/13ae3047f2024a78b3cdda7d1b1389d9.1000x1000x1.jpg',
#    'id': 295423,
#    'lyrics_owner_id': 246999,
#    'path': '/Lea-michele-cannonball-lyrics',
#    'primary_artist': {'api_path': '/artists/108090',
#     'header_image_url': 'https://images.genius.com/16478bcb069be9a116eb4891f3025848.544x781x1.jpg',
#     'id': 108090,
#     'image_url': 'https://images.genius.com/16478bcb069be9a116eb4891f3025848.544x781x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Lea Michele',
#     'url': 'http://genius.com/artists/Lea-michele'},
#    'pyongs_count': 7,
#    'stats': {'hot': False, 'pageviews': 11636, 'unreviewed_annotations': 4},
#    'title': 'Cannonball',
#    'url': 'http://genius.com/Lea-michele-cannonball-lyrics'},
#   {'annotation_count': 9,
#    'api_path': '/songs/582559',
#    'full_title': 'Caught In the Middle by\xa0Charli\xa0XCX',
#    'header_image_thumbnail_url': 'https://images.genius.com/5fe34705c7af82886d5c883070b051bd.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/5fe34705c7af82886d5c883070b051bd.1000x1000x1.jpg',
#    'id': 582559,
#    'lyrics_owner_id': 1292898,
#    'path': '/Charli-xcx-caught-in-the-middle-lyrics',
#    'primary_artist': {'api_path': '/artists/45349',
#     'header_image_url': 'https://images.genius.com/52ee27428564701e0dd97985942cc893.245x245x30.gif',
#     'id': 45349,
#     'image_url': 'https://images.genius.com/52ee27428564701e0dd97985942cc893.245x245x30.gif',
#     'iq': 1075,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Charli XCX',
#     'url': 'http://genius.com/artists/Charli-xcx'},
#    'pyongs_count': 3,
#    'stats': {'hot': False, 'unreviewed_annotations': 3},
#    'title': 'Caught In the Middle',
#    'url': 'http://genius.com/Charli-xcx-caught-in-the-middle-lyrics'},
#   {'annotation_count': 4,
#    'api_path': '/songs/465228',
#    'full_title': 'Cheated by\xa0Mike\xa0Posner',
#    'header_image_thumbnail_url': 'https://images.genius.com/4b46ede5193a24e895319011149f06c2.220x220x1.jpg',
#    'header_image_url': 'https://images.genius.com/4b46ede5193a24e895319011149f06c2.220x220x1.jpg',
#    'id': 465228,
#    'lyrics_owner_id': 303,
#    'path': '/Mike-posner-cheated-lyrics',
#    'primary_artist': {'api_path': '/artists/654',
#     'header_image_url': 'https://images.genius.com/7e444f7979517ff15853bdb89e4c5780.946x532x1.jpg',
#     'id': 654,
#     'image_url': 'https://images.genius.com/7e444f7979517ff15853bdb89e4c5780.946x532x1.jpg',
#     'iq': 8698,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Mike Posner',
#     'url': 'http://genius.com/artists/Mike-posner'},
#    'pyongs_count': 3,
#    'stats': {'hot': False, 'unreviewed_annotations': 3},
#    'title': 'Cheated',
#    'url': 'http://genius.com/Mike-posner-cheated-lyrics'},
#   {'annotation_count': 10,
#    'api_path': '/songs/193691',
#    'full_title': 'Circus by\xa0Britney\xa0Spears',
#    'header_image_thumbnail_url': 'https://images.genius.com/e23ca46f7425bbbb0272703064417254.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/e23ca46f7425bbbb0272703064417254.1000x1000x1.jpg',
#    'id': 193691,
#    'lyrics_owner_id': 230686,
#    'path': '/Britney-spears-circus-lyrics',
#    'primary_artist': {'api_path': '/artists/1052',
#     'header_image_url': 'https://images.genius.com/2e0f186549b52e6f5d65a10e073d0a8d.1000x625x1.jpg',
#     'id': 1052,
#     'image_url': 'https://images.genius.com/2e0f186549b52e6f5d65a10e073d0a8d.1000x625x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Britney Spears',
#     'url': 'http://genius.com/artists/Britney-spears'},
#    'pyongs_count': 11,
#    'stats': {'hot': False, 'unreviewed_annotations': 3},
#    'title': 'Circus',
#    'url': 'http://genius.com/Britney-spears-circus-lyrics'},
#   {'annotation_count': 24,
#    'api_path': '/songs/109839',
#    'full_title': "C'mon by\xa0Kesha",
#    'header_image_thumbnail_url': 'https://images.genius.com/955bbbcc6a3ba8e2387cbd0cf0ddb547.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/955bbbcc6a3ba8e2387cbd0cf0ddb547.1000x1000x1.jpg',
#    'id': 109839,
#    'lyrics_owner_id': 93685,
#    'path': '/Kesha-cmon-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 13,
#    'stats': {'hot': False, 'pageviews': 5791, 'unreviewed_annotations': 16},
#    'title': "C'mon",
#    'url': 'http://genius.com/Kesha-cmon-lyrics'},
#   {'annotation_count': 6,
#    'api_path': '/songs/2481759',
#    'full_title': 'Cold Water by\xa0Major\xa0Lazer (Ft.\xa0Justin\xa0Bieber & MØ)',
#    'header_image_thumbnail_url': 'https://images.genius.com/4302666c3111931e710dcad0c01ce0e3.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/4302666c3111931e710dcad0c01ce0e3.1000x1000x1.jpg',
#    'id': 2481759,
#    'lyrics_owner_id': 104344,
#    'path': '/Major-lazer-cold-water-lyrics',
#    'primary_artist': {'api_path': '/artists/665',
#     'header_image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'id': 665,
#     'image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Major Lazer',
#     'url': 'http://genius.com/artists/Major-lazer'},
#    'pyongs_count': 55,
#    'stats': {'concurrents': 31,
#     'hot': False,
#     'pageviews': 804284,
#     'unreviewed_annotations': 0},
#    'title': 'Cold Water',
#    'url': 'http://genius.com/Major-lazer-cold-water-lyrics'},
#   {'annotation_count': 7,
#    'api_path': '/songs/2836774',
#    'full_title': 'Cold Water (Remix) by\xa0Major\xa0Lazer (Ft.\xa0Gucci\xa0Mane, Justin\xa0Bieber & MØ)',
#    'header_image_thumbnail_url': 'https://images.genius.com/bf05cfdd2fbb67a9dfc76da4cd20c8e2.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/bf05cfdd2fbb67a9dfc76da4cd20c8e2.612x612x1.jpg',
#    'id': 2836774,
#    'lyrics_owner_id': 282633,
#    'path': '/Major-lazer-cold-water-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/665',
#     'header_image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'id': 665,
#     'image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Major Lazer',
#     'url': 'http://genius.com/artists/Major-lazer'},
#    'pyongs_count': 3,
#    'stats': {'hot': False, 'unreviewed_annotations': 1},
#    'title': 'Cold Water (Remix)',
#    'url': 'http://genius.com/Major-lazer-cold-water-remix-lyrics'},
#   {'annotation_count': 0,
#    'api_path': '/songs/2857919',
#    'full_title': 'Cold Water (Shew Remix) by\xa0Major\xa0Lazer (Ft.\xa0Justin\xa0Bieber & MØ)',
#    'header_image_thumbnail_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.300x222x1.jpg',
#    'header_image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#    'id': 2857919,
#    'lyrics_owner_id': 3708693,
#    'path': '/Major-lazer-cold-water-shew-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/665',
#     'header_image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'id': 665,
#     'image_url': 'https://images.genius.com/16czjdodz8lhalb2djzy8hoht.406x300x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Major Lazer',
#     'url': 'http://genius.com/artists/Major-lazer'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Cold Water (Shew Remix)',
#    'url': 'http://genius.com/Major-lazer-cold-water-shew-remix-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/2297280',
#    'full_title': 'Come With Me by\xa0Benny\xa0Blanco',
#    'header_image_thumbnail_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.300x194x1.jpg',
#    'header_image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#    'id': 2297280,
#    'lyrics_owner_id': 128849,
#    'path': '/Benny-blanco-come-with-me-lyrics',
#    'primary_artist': {'api_path': '/artists/28906',
#     'header_image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#     'id': 28906,
#     'image_url': 'https://images.genius.com/32ae6b05153b31f9aa1415760a63520f.620x400x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Benny Blanco',
#     'url': 'http://genius.com/artists/Benny-blanco'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Come With Me',
#    'url': 'http://genius.com/Benny-blanco-come-with-me-lyrics'},
#   {'annotation_count': 26,
#    'api_path': '/songs/100016',
#    'full_title': 'Crazy Kids by\xa0Kesha',
#    'header_image_thumbnail_url': 'https://images.genius.com/a5eb04e2039deb7c59c1e4755f11d219.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/a5eb04e2039deb7c59c1e4755f11d219.960x960x1.jpg',
#    'id': 100016,
#    'lyrics_owner_id': 93685,
#    'path': '/Kesha-crazy-kids-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 13,
#    'stats': {'hot': False, 'pageviews': 19212, 'unreviewed_annotations': 0},
#    'title': 'Crazy Kids',
#    'url': 'http://genius.com/Kesha-crazy-kids-lyrics'},
#   {'annotation_count': 12,
#    'api_path': '/songs/173297',
#    'full_title': 'Crazy Kids (Remix) by\xa0Kesha (Ft.\xa0\u200bwill.i.am)',
#    'header_image_thumbnail_url': 'https://images.genius.com/7e56500a59933473e1e7de04b9cf90f9.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/7e56500a59933473e1e7de04b9cf90f9.1000x1000x1.jpg',
#    'id': 173297,
#    'lyrics_owner_id': 141291,
#    'path': '/Kesha-crazy-kids-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 1,
#    'stats': {'hot': False, 'pageviews': 10477, 'unreviewed_annotations': 0},
#    'title': 'Crazy Kids (Remix)',
#    'url': 'http://genius.com/Kesha-crazy-kids-remix-lyrics'},
#   {'annotation_count': 20,
#    'api_path': '/songs/25983',
#    'full_title': 'Dancing With Tears In My Eyes by\xa0Kesha',
#    'header_image_thumbnail_url': 'https://images.genius.com/d72a6ba54d784cb5b0b87f1ccd455769.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d72a6ba54d784cb5b0b87f1ccd455769.600x600x1.jpg',
#    'id': 25983,
#    'lyrics_owner_id': 50,
#    'path': '/Kesha-dancing-with-tears-in-my-eyes-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 7,
#    'stats': {'hot': False, 'unreviewed_annotations': 18},
#    'title': 'Dancing With Tears In My Eyes',
#    'url': 'http://genius.com/Kesha-dancing-with-tears-in-my-eyes-lyrics'},
#   {'annotation_count': 22,
#    'api_path': '/songs/89794',
#    'full_title': 'Diamonds by\xa0Rihanna',
#    'header_image_thumbnail_url': 'https://images.genius.com/d31652f8a9f5ae2afc54525cff56b883.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d31652f8a9f5ae2afc54525cff56b883.1000x1000x1.jpg',
#    'id': 89794,
#    'lyrics_owner_id': 113967,
#    'path': '/Rihanna-diamonds-lyrics',
#    'primary_artist': {'api_path': '/artists/89',
#     'header_image_url': 'https://images.genius.com/8353714f907477857490bd7411edb550.600x468x1.jpg',
#     'id': 89,
#     'image_url': 'https://images.genius.com/2be3181b8d8f6914509fbff4770c854e.600x318x1.png',
#     'iq': 1474,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Rihanna',
#     'url': 'http://genius.com/artists/Rihanna'},
#    'pyongs_count': 45,
#    'stats': {'concurrents': 2,
#     'hot': False,
#     'pageviews': 235195,
#     'unreviewed_annotations': 0},
#    'title': 'Diamonds',
#    'url': 'http://genius.com/Rihanna-diamonds-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/2215702',
#    'full_title': 'Diamonds by\xa0Kaysha',
#    'header_image_thumbnail_url': 'https://4.bp.blogspot.com/-fzWq0Uv9bKM/UTdVphsLgXI/AAAAAAAAHTE/E_WIklf_-I0/s1600/Kaysha+diamonds+by+nordarciopro.jpg',
#    'header_image_url': 'https://4.bp.blogspot.com/-fzWq0Uv9bKM/UTdVphsLgXI/AAAAAAAAHTE/E_WIklf_-I0/s1600/Kaysha+diamonds+by+nordarciopro.jpg',
#    'id': 2215702,
#    'lyrics_owner_id': 1549345,
#    'path': '/Kaysha-diamonds-lyrics',
#    'primary_artist': {'api_path': '/artists/371036',
#     'header_image_url': 'https://images.rapgenius.com/avatars/medium/4fac0c6dfea9416ff61160bc932ce785',
#     'id': 371036,
#     'image_url': 'https://images.rapgenius.com/avatars/medium/4fac0c6dfea9416ff61160bc932ce785',
#     'iq': 854,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': 'Kaysha',
#     'url': 'http://genius.com/artists/Kaysha'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Diamonds',
#    'url': 'http://genius.com/Kaysha-diamonds-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/384706',
#    'full_title': 'Diamonds (Flo Rida Remix) by\xa0Rihanna (Ft.\xa0Flo\xa0Rida)',
#    'header_image_thumbnail_url': 'https://images.genius.com/2be3181b8d8f6914509fbff4770c854e.300x159x1.png',
#    'header_image_url': 'https://images.genius.com/2be3181b8d8f6914509fbff4770c854e.600x318x1.png',
#    'id': 384706,
#    'lyrics_owner_id': 696607,
#    'path': '/Rihanna-diamonds-flo-rida-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/89',
#     'header_image_url': 'https://images.genius.com/8353714f907477857490bd7411edb550.600x468x1.jpg',
#     'id': 89,
#     'image_url': 'https://images.genius.com/2be3181b8d8f6914509fbff4770c854e.600x318x1.png',
#     'iq': 1474,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Rihanna',
#     'url': 'http://genius.com/artists/Rihanna'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Diamonds (Flo Rida Remix)',
#    'url': 'http://genius.com/Rihanna-diamonds-flo-rida-remix-lyrics'},
#   {'annotation_count': 31,
#    'api_path': '/songs/97945',
#    'full_title': 'Diamonds (Remix) by\xa0Rihanna (Ft.\xa0Kanye\xa0West)',
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/52519142b73eda372a1aeae490854d21.300x300x1.jpg',
#    'header_image_url': 'https://images.rapgenius.com/52519142b73eda372a1aeae490854d21.500x500x1.jpg',
#    'id': 97945,
#    'lyrics_owner_id': 5738,
#    'path': '/Rihanna-diamonds-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/89',
#     'header_image_url': 'https://images.genius.com/8353714f907477857490bd7411edb550.600x468x1.jpg',
#     'id': 89,
#     'image_url': 'https://images.genius.com/2be3181b8d8f6914509fbff4770c854e.600x318x1.png',
#     'iq': 1474,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Rihanna',
#     'url': 'http://genius.com/artists/Rihanna'},
#    'pyongs_count': 31,
#    'stats': {'hot': False, 'pageviews': 443758, 'unreviewed_annotations': 0},
#    'title': 'Diamonds (Remix)',
#    'url': 'http://genius.com/Rihanna-diamonds-remix-lyrics'},
#   {'annotation_count': 12,
#    'api_path': '/songs/89732',
#    'full_title': 'Die Young by\xa0Kesha',
#    'header_image_thumbnail_url': 'https://images.genius.com/d1f823a12d9a8c98cf5221b6f806f947.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/d1f823a12d9a8c98cf5221b6f806f947.1000x1000x1.jpg',
#    'id': 89732,
#    'lyrics_owner_id': 12128,
#    'path': '/Kesha-die-young-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 19,
#    'stats': {'hot': False, 'pageviews': 48657, 'unreviewed_annotations': 0},
#    'title': 'Die Young',
#    'url': 'http://genius.com/Kesha-die-young-lyrics'},
#   {'annotation_count': 38,
#    'api_path': '/songs/100391',
#    'full_title': 'Die Young (Remix) by\xa0Kesha (Ft.\xa0Becky\xa0G, Juicy\xa0J & Wiz\xa0Khalifa)',
#    'header_image_thumbnail_url': 'https://images.genius.com/4fe6033b5b4e30153e0cdf93fdb04f1b.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/4fe6033b5b4e30153e0cdf93fdb04f1b.1000x1000x1.jpg',
#    'id': 100391,
#    'lyrics_owner_id': 93685,
#    'path': '/Kesha-die-young-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/1519',
#     'header_image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'id': 1519,
#     'image_url': 'https://images.genius.com/b47c61e88820ea4ff22ff7174b3fcc75.713x1000x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Kesha',
#     'url': 'http://genius.com/artists/Kesha'},
#    'pyongs_count': 5,
#    'stats': {'hot': False, 'pageviews': 31827, 'unreviewed_annotations': 6},
#    'title': 'Die Young (Remix)',
#    'url': 'http://genius.com/Kesha-die-young-remix-lyrics'},
#   {'annotation_count': 34,
#    'api_path': '/songs/403031',
#    'full_title': "Don't by\xa0Ed\xa0Sheeran",
#    'header_image_thumbnail_url': 'https://images.genius.com/b5a9b47cf8edad24fb3328226085c029.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/b5a9b47cf8edad24fb3328226085c029.600x600x1.jpg',
#    'id': 403031,
#    'lyrics_owner_id': 321196,
#    'path': '/Ed-sheeran-dont-lyrics',
#    'primary_artist': {'api_path': '/artists/12418',
#     'header_image_url': 'https://images.genius.com/c0d50f5dcff34dbe37cc2b09139a8087.1000x750x1.jpg',
#     'id': 12418,
#     'image_url': 'https://images.genius.com/c0d50f5dcff34dbe37cc2b09139a8087.1000x750x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Ed Sheeran',
#     'url': 'http://genius.com/artists/Ed-sheeran'},
#    'pyongs_count': 372,
#    'stats': {'hot': False, 'pageviews': 519649, 'unreviewed_annotations': 4},
#    'title': "Don't",
#    'url': 'http://genius.com/Ed-sheeran-dont-lyrics'},
#   {'annotation_count': 10,
#    'api_path': '/songs/499519',
#    'full_title': "Don't (Rick Ross Remix) by\xa0Ed\xa0Sheeran (Ft.\xa0Rick\xa0Ross)",
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/9bc03fccfa829357e34aae9ca1b85829.300x300x1.jpg',
#    'header_image_url': 'https://images.rapgenius.com/9bc03fccfa829357e34aae9ca1b85829.500x500x1.jpg',
#    'id': 499519,
#    'lyrics_owner_id': 672397,
#    'path': '/Ed-sheeran-dont-rick-ross-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/12418',
#     'header_image_url': 'https://images.genius.com/c0d50f5dcff34dbe37cc2b09139a8087.1000x750x1.jpg',
#     'id': 12418,
#     'image_url': 'https://images.genius.com/c0d50f5dcff34dbe37cc2b09139a8087.1000x750x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Ed Sheeran',
#     'url': 'http://genius.com/artists/Ed-sheeran'},
#    'pyongs_count': 20,
#    'stats': {'hot': False, 'pageviews': 23644, 'unreviewed_annotations': 2},
#    'title': "Don't (Rick Ross Remix)",
#    'url': 'http://genius.com/Ed-sheeran-dont-rick-ross-remix-lyrics'},
#   {'annotation_count': 19,
#    'api_path': '/songs/323852',
#    'full_title': "Don't Trust Me by\xa0Mike\xa0Posner (Ft.\xa03OH!3 & Kid\xa0Cudi)",
#    'header_image_thumbnail_url': 'https://images.genius.com/3890118af7aae093437bcf176d6c45e2.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/3890118af7aae093437bcf176d6c45e2.500x500x1.jpg',
#    'id': 323852,
#    'lyrics_owner_id': 357361,
#    'path': '/Mike-posner-dont-trust-me-lyrics',
#    'primary_artist': {'api_path': '/artists/654',
#     'header_image_url': 'https://images.genius.com/7e444f7979517ff15853bdb89e4c5780.946x532x1.jpg',
#     'id': 654,
#     'image_url': 'https://images.genius.com/7e444f7979517ff15853bdb89e4c5780.946x532x1.jpg',
#     'iq': 8698,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Mike Posner',
#     'url': 'http://genius.com/artists/Mike-posner'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': "Don't Trust Me",
#    'url': 'http://genius.com/Mike-posner-dont-trust-me-lyrics'},
#   {'annotation_count': 12,
#    'api_path': '/songs/105094',
#    'full_title': "Don't Trust Me by\xa03OH!3",
#    'header_image_thumbnail_url': 'https://images.genius.com/3076494d47f525aec8085b2df7a7fc4c.280x280x1.jpg',
#    'header_image_url': 'https://images.genius.com/3076494d47f525aec8085b2df7a7fc4c.280x280x1.jpg',
#    'id': 105094,
#    'lyrics_owner_id': 19559,
#    'path': '/3oh-3-dont-trust-me-lyrics',
#    'primary_artist': {'api_path': '/artists/7092',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'id': 7092,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'iq': 0,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': '3OH!3',
#     'url': 'http://genius.com/artists/3oh-3'},
#    'pyongs_count': 11,
#    'stats': {'hot': False, 'pageviews': 24186, 'unreviewed_annotations': 2},
#    'title': "Don't Trust Me",
#    'url': 'http://genius.com/3oh-3-dont-trust-me-lyrics'},
#   {'annotation_count': 14,
#    'api_path': '/songs/50134',
#    'full_title': "Don't Trust Me (Remix) by\xa03OH!3 (Ft.\xa0Kid\xa0Cudi)",
#    'header_image_thumbnail_url': 'https://images.genius.com/4de511152bf020f7ec534d76fbc97793.300x300x1.png',
#    'header_image_url': 'https://images.genius.com/4de511152bf020f7ec534d76fbc97793.1000x1000x1.png',
#    'id': 50134,
#    'lyrics_owner_id': 10339,
#    'path': '/3oh-3-dont-trust-me-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/7092',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'id': 7092,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'iq': 0,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': '3OH!3',
#     'url': 'http://genius.com/artists/3oh-3'},
#    'pyongs_count': 1,
#    'stats': {'hot': False, 'pageviews': 21168, 'unreviewed_annotations': 13},
#    'title': "Don't Trust Me (Remix)",
#    'url': 'http://genius.com/3oh-3-dont-trust-me-remix-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/645107',
#    'full_title': "Don't Trust Me (Tinie Tempah Remix) by\xa03OH!3 (Ft.\xa0Tinie\xa0Tempah)",
#    'header_image_thumbnail_url': 'https://images.genius.com/0253203a236c440e8f8df956d4b54e7f.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/0253203a236c440e8f8df956d4b54e7f.500x500x1.jpg',
#    'id': 645107,
#    'lyrics_owner_id': 321196,
#    'path': '/3oh-3-dont-trust-me-tinie-tempah-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/7092',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'id': 7092,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'iq': 0,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': '3OH!3',
#     'url': 'http://genius.com/artists/3oh-3'},
#    'pyongs_count': 2,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': "Don't Trust Me (Tinie Tempah Remix)",
#    'url': 'http://genius.com/3oh-3-dont-trust-me-tinie-tempah-remix-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/1932272',
#    'full_title': "Don't Wait (Benny Blanco Remix) by\xa0Mapei",
#    'header_image_thumbnail_url': 'https://images.genius.com/86ca2bfeb1bee6581429dd6be904f7cd.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/86ca2bfeb1bee6581429dd6be904f7cd.1000x1000x1.jpg',
#    'id': 1932272,
#    'lyrics_owner_id': 1549345,
#    'path': '/Mapei-dont-wait-benny-blanco-remix-lyrics',
#    'primary_artist': {'api_path': '/artists/146039',
#     'header_image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'id': 146039,
#     'image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Mapei',
#     'url': 'http://genius.com/artists/Mapei'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': "Don't Wait (Benny Blanco Remix)",
#    'url': 'http://genius.com/Mapei-dont-wait-benny-blanco-remix-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/954205',
#    'full_title': 'Double Vision by\xa03OH!3',
#    'header_image_thumbnail_url': 'https://images.genius.com/564d0dd1aad30c4be6f790dbc1906415.300x298x1.jpg',
#    'header_image_url': 'https://images.genius.com/564d0dd1aad30c4be6f790dbc1906415.600x596x1.jpg',
#    'id': 954205,
#    'lyrics_owner_id': 1549345,
#    'path': '/3oh-3-double-vision-lyrics',
#    'primary_artist': {'api_path': '/artists/7092',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'id': 7092,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/3OH3%20in%20the%20shack.jpg',
#     'iq': 0,
#     'is_meme_verified': False,
#     'is_verified': True,
#     'name': '3OH!3',
#     'url': 'http://genius.com/artists/3oh-3'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Double Vision',
#    'url': 'http://genius.com/3oh-3-double-vision-lyrics'},
#   {'annotation_count': 9,
#    'api_path': '/songs/193730',
#    'full_title': '(Drop Dead) Beautiful by\xa0Britney\xa0Spears (Ft.\xa0Sabi)',
#    'header_image_thumbnail_url': 'https://images.genius.com/a34abf496e53ab602aa2070585b9b90d.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/a34abf496e53ab602aa2070585b9b90d.1000x1000x1.jpg',
#    'id': 193730,
#    'lyrics_owner_id': 225680,
#    'path': '/Britney-spears-drop-dead-beautiful-lyrics',
#    'primary_artist': {'api_path': '/artists/1052',
#     'header_image_url': 'https://images.genius.com/2e0f186549b52e6f5d65a10e073d0a8d.1000x625x1.jpg',
#     'id': 1052,
#     'image_url': 'https://images.genius.com/2e0f186549b52e6f5d65a10e073d0a8d.1000x625x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Britney Spears',
#     'url': 'http://genius.com/artists/Britney-spears'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 7},
#    'title': '(Drop Dead) Beautiful',
#    'url': 'http://genius.com/Britney-spears-drop-dead-beautiful-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/1550003',
#    'full_title': 'Dynamite by\xa0China\xa0Anne Mcclain',
#    'header_image_thumbnail_url': 'https://images.genius.com/b4b33c31ccb16b0b22cb1dbf5157f2dd.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/b4b33c31ccb16b0b22cb1dbf5157f2dd.500x500x1.jpg',
#    'id': 1550003,
#    'lyrics_owner_id': 1549345,
#    'path': '/China-anne-mcclain-dynamite-lyrics',
#    'primary_artist': {'api_path': '/artists/20882',
#     'header_image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'id': 20882,
#     'image_url': 'https://assets.genius.com/images/default_cover_art.png?1474058859',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'China Anne Mcclain',
#     'url': 'http://genius.com/artists/China-anne-mcclain'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Dynamite',
#    'url': 'http://genius.com/China-anne-mcclain-dynamite-lyrics'},
#   {'annotation_count': 5,
#    'api_path': '/songs/5807',
#    'full_title': 'Dynamite by\xa0Taio\xa0Cruz',
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/625929598b32e1092f57f563f7f83cf5.220x220x1.jpg',
#    'header_image_url': 'https://images.rapgenius.com/625929598b32e1092f57f563f7f83cf5.220x220x1.jpg',
#    'id': 5807,
#    'lyrics_owner_id': 7,
#    'path': '/Taio-cruz-dynamite-lyrics',
#    'primary_artist': {'api_path': '/artists/2395',
#     'header_image_url': 'https://images.genius.com/23959b8d50bc4fcf771a57dc0bc06341.500x500x1.png',
#     'id': 2395,
#     'image_url': 'https://images.genius.com/23959b8d50bc4fcf771a57dc0bc06341.500x500x1.png',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Taio Cruz',
#     'url': 'http://genius.com/artists/Taio-cruz'},
#    'pyongs_count': 13,
#    'stats': {'hot': False, 'pageviews': 23569, 'unreviewed_annotations': 1},
#    'title': 'Dynamite',
#    'url': 'http://genius.com/Taio-cruz-dynamite-lyrics'},
#   {'annotation_count': 9,
#    'api_path': '/songs/1829',
#    'full_title': 'Eenie Meenie by\xa0Sean\xa0Kingston (Ft.\xa0Justin\xa0Bieber)',
#    'header_image_thumbnail_url': 'https://images.rapgenius.com/6dc3e535a8ce5104ef6d95d9ede81fd1.300x364x1.jpg',
#    'header_image_url': 'https://images.rapgenius.com/6dc3e535a8ce5104ef6d95d9ede81fd1.824x1000x1.jpg',
#    'id': 1829,
#    'lyrics_owner_id': 7,
#    'path': '/Sean-kingston-eenie-meenie-lyrics',
#    'primary_artist': {'api_path': '/artists/933',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/bf4bc21e822540a1ba59d02.png',
#     'id': 933,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/bf4bc21e822540a1ba59d02.png',
#     'iq': 406,
#     'is_meme_verified': True,
#     'is_verified': True,
#     'name': 'Sean Kingston',
#     'url': 'http://genius.com/artists/Sean-kingston'},
#    'pyongs_count': 6,
#    'stats': {'hot': False, 'pageviews': 19016, 'unreviewed_annotations': 1},
#    'title': 'Eenie Meenie',
#    'url': 'http://genius.com/Sean-kingston-eenie-meenie-lyrics'},
#   {'annotation_count': 2,
#    'api_path': '/songs/734209',
#    'full_title': 'Em Memória by\xa0C4bal',
#    'header_image_thumbnail_url': 'https://i.embed.ly/1/display?key=fc778e44915911e088ae4040f9f86dcd&url=http%3A%2F%2Fwww.rapnacionaldownload.com.br%2Fwp-content%2Fuploads%2F2012%2F03%2FC4bal-Opera%25C3%25A7%25C3%25A3o-H%25C3%25A9rcules.jpg',
#    'header_image_url': 'https://i.embed.ly/1/display?key=fc778e44915911e088ae4040f9f86dcd&url=http%3A%2F%2Fwww.rapnacionaldownload.com.br%2Fwp-content%2Fuploads%2F2012%2F03%2FC4bal-Opera%25C3%25A7%25C3%25A3o-H%25C3%25A9rcules.jpg',
#    'id': 734209,
#    'lyrics_owner_id': 150732,
#    'path': '/C4bal-em-memoria-lyrics',
#    'primary_artist': {'api_path': '/artists/16728',
#     'header_image_url': 'https://images.genius.com/373c96149928d8814cabe26f4187ef5c.500x500x1.jpg',
#     'id': 16728,
#     'image_url': 'https://images.genius.com/373c96149928d8814cabe26f4187ef5c.500x500x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'C4bal',
#     'url': 'http://genius.com/artists/C4bal'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'unreviewed_annotations': 0},
#    'title': 'Em Memória',
#    'url': 'http://genius.com/C4bal-em-memoria-lyrics'},
#   {'annotation_count': 1,
#    'api_path': '/songs/2855688',
#    'full_title': 'Faith by\xa0Stevie\xa0Wonder (Ft.\xa0Ariana\xa0Grande)',
#    'header_image_thumbnail_url': 'https://s3.amazonaws.com/rapgenius/1361469524_stevie-wonder%20in%20the%201970s.jpeg',
#    'header_image_url': 'https://s3.amazonaws.com/rapgenius/1361469524_stevie-wonder%20in%20the%201970s.jpeg',
#    'id': 2855688,
#    'lyrics_owner_id': 3499648,
#    'path': '/Stevie-wonder-faith-lyrics',
#    'primary_artist': {'api_path': '/artists/1602',
#     'header_image_url': 'https://s3.amazonaws.com/rapgenius/1361469524_stevie-wonder%20in%20the%201970s.jpeg',
#     'id': 1602,
#     'image_url': 'https://s3.amazonaws.com/rapgenius/1361469524_stevie-wonder%20in%20the%201970s.jpeg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Stevie Wonder',
#     'url': 'http://genius.com/artists/Stevie-wonder'},
#    'pyongs_count': 1,
#    'stats': {'hot': False, 'unreviewed_annotations': 1},
#    'title': 'Faith',
#    'url': 'http://genius.com/Stevie-wonder-faith-lyrics'},
#   {'annotation_count': 5,
#    'api_path': '/songs/2261648',
#    'full_title': 'Fire And The Flood by\xa0Vance\xa0Joy',
#    'header_image_thumbnail_url': 'https://images.genius.com/8d882221da4214f746547ad35736165e.300x300x1.jpg',
#    'header_image_url': 'https://images.genius.com/8d882221da4214f746547ad35736165e.600x600x1.jpg',
#    'id': 2261648,
#    'lyrics_owner_id': 266331,
#    'path': '/Vance-joy-fire-and-the-flood-lyrics',
#    'primary_artist': {'api_path': '/artists/81818',
#     'header_image_url': 'https://images.genius.com/ef8f3d50ee35e8826ed921325b7b3017.640x960x1.jpg',
#     'id': 81818,
#     'image_url': 'https://images.genius.com/ef8f3d50ee35e8826ed921325b7b3017.640x960x1.jpg',
#     'is_meme_verified': False,
#     'is_verified': False,
#     'name': 'Vance Joy',
#     'url': 'http://genius.com/artists/Vance-joy'},
#    'pyongs_count': None,
#    'stats': {'hot': False, 'pageviews': 33151, 'unreviewed_annotations': 0},
#    'title': 'Fire And The Flood',
#    'url': 'http://genius.com/Vance-joy-fire-and-the-flood-lyrics'}]}

# %%
artist_ids_stripped = [a[1] for a in artist_ids_filtered]
artist_info = Pool(100).map(api.get_artist, artist_ids_stripped)
artist_info[9]
# Out:
# {'alternate_names': ["Curtis '50 Cent' Jackson", 'Curtis Jackson'],
#  'api_path': '/artists/108',
#  'current_user_metadata': {'interactions': {'following': False},
#   'permissions': ['view_activity_stream']},
#  'description': {'plain': "Curtis James Jackson III (born July 6, 1975), better known by his stage name 50 Cent, is an American rapper, entrepreneur, investor, record producer, and actor.\n\nAfter recording a never-released album with Columbia, 50 got on his grind and rose to fame via a string of well-received mixtapes, thus setting the template for rap stardom in the modern era.\n\n50’s crowning success came in 2003 with the release of the album Get Rich or Die Tryin' which sold 872,000 copies in four days and was certified 8x platinum by the RIAA. Since that monster hit, he has continued to make music while also delving into movies, sports drinks, video games, mass charity campaigns and more."},
#  'description_annotation': {'_type': 'referent',
#   'annotatable': {'api_path': '/artists/108',
#    'context': None,
#    'id': 108,
#    'image_url': 'https://s3.amazonaws.com/rapgenius/tumblr_mqqafeN3DE1qewjaco1_500.jpg',
#    'link_title': '50 Cent',
#    'title': '50 Cent',
#    'type': 'Artist',
#    'url': 'http://genius.com/artists/50-cent'},
#   'annotations': [{'api_path': '/annotations/6925710',
#     'authors': [{'attribution': 0.8376068376068376,
#       'pinned_role': None,
#       'user': {'api_path': '/users/2',
#        'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#          'url': 'https://assets.genius.com/images/default_avatar_300.png?1474058859'},
#         'small': {'bounding_box': {'height': 100, 'width': 100},
#          'url': 'https://assets.genius.com/images/default_avatar_100.png?1474058859'},
#         'thumb': {'bounding_box': {'height': 32, 'width': 32},
#          'url': 'https://assets.genius.com/images/default_avatar_32.png?1474058859'},
#         'tiny': {'bounding_box': {'height': 16, 'width': 16},
#          'url': 'https://assets.genius.com/images/default_avatar_16.png?1474058859'}},
#        'current_user_metadata': {'interactions': {'following': False},
#         'permissions': []},
#        'header_image_url': 'https://assets.genius.com/images/default_avatar_300.png?1474058859',
#        'human_readable_role_for_display': 'Moderator',
#        'id': 2,
#        'iq': 96274,
#        'login': 'hellrel',
#        'name': 'hellrel',
#        'role_for_display': 'moderator',
#        'url': 'http://genius.com/hellrel'}},
#      {'attribution': 0.16239316239316237,
#       'pinned_role': None,
#       'user': {'api_path': '/users/866162',
#        'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#          'url': 'https://images.rapgenius.com/avatars/medium/c062962136459e25d67ef3bdff70f437'},
#         'small': {'bounding_box': {'height': 100, 'width': 100},
#          'url': 'https://images.rapgenius.com/avatars/small/c062962136459e25d67ef3bdff70f437'},
#         'thumb': {'bounding_box': {'height': 32, 'width': 32},
#          'url': 'https://images.rapgenius.com/avatars/thumb/c062962136459e25d67ef3bdff70f437'},
#         'tiny': {'bounding_box': {'height': 16, 'width': 16},
#          'url': 'https://images.rapgenius.com/avatars/tiny/c062962136459e25d67ef3bdff70f437'}},
#        'current_user_metadata': {'interactions': {'following': False},
#         'permissions': []},
#        'header_image_url': 'https://images.rapgenius.com/avatars/medium/c062962136459e25d67ef3bdff70f437',
#        'human_readable_role_for_display': 'Editor',
#        'id': 866162,
#        'iq': 19002,
#        'login': 'TheOriginalRap',
#        'name': 'TheOriginalRap',
#        'role_for_display': 'editor',
#        'url': 'http://genius.com/TheOriginalRap'}}],
#     'body': {'plain': "Curtis James Jackson III (born July 6, 1975), better known by his stage name 50 Cent, is an American rapper, entrepreneur, investor, record producer, and actor.\n\nAfter recording a never-released album with Columbia, 50 got on his grind and rose to fame via a string of well-received mixtapes, thus setting the template for rap stardom in the modern era.\n\n50’s crowning success came in 2003 with the release of the album Get Rich or Die Tryin' which sold 872,000 copies in four days and was certified 8x platinum by the RIAA. Since that monster hit, he has continued to make music while also delving into movies, sports drinks, video games, mass charity campaigns and more."},
#     'comment_count': 3,
#     'community': True,
#     'cosigned_by': [],
#     'current_user_metadata': {'interactions': {'cosign': False,
#       'pyong': False,
#       'vote': None},
#      'permissions': ['create_comment']},
#     'has_voters': True,
#     'id': 6925710,
#     'pinned': False,
#     'share_url': 'http://genius.com/6925710',
#     'source': None,
#     'state': 'accepted',
#     'url': 'http://genius.com/6925710/50-cent/50-cent',
#     'verified': False,
#     'verified_by': None,
#     'votes_total': 15}],
#   'annotator_id': 2,
#   'annotator_login': 'hellrel',
#   'api_path': '/referents/6925710',
#   'classification': 'accepted',
#   'fragment': '50 Cent',
#   'id': 6925710,
#   'is_description': True,
#   'path': '/6925710/50-cent/50-cent',
#   'range': {'content': '50 Cent'},
#   'song_id': None,
#   'url': 'http://genius.com/6925710/50-cent/50-cent',
#   'verified_annotator_ids': []},
#  'facebook_name': '50cent',
#  'followers_count': 3559,
#  'header_image_url': 'https://s3.amazonaws.com/rapgenius/tumblr_mqqafeN3DE1qewjaco1_500.jpg',
#  'id': 108,
#  'image_url': 'https://s3.amazonaws.com/rapgenius/tumblr_mqqafeN3DE1qewjaco1_500.jpg',
#  'instagram_name': '50cent',
#  'iq': 2772,
#  'is_meme_verified': True,
#  'is_verified': True,
#  'name': '50 Cent',
#  'twitter_name': '50cent',
#  'url': 'http://genius.com/artists/50-cent',
#  'user': {'api_path': '/users/128866',
#   'avatar': {'medium': {'bounding_box': {'height': 400, 'width': 300},
#     'url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/1358290527_128866_50-cent.jpeg'},
#    'small': {'bounding_box': {'height': 100, 'width': 100},
#     'url': 'https://s3.amazonaws.com/rapgenius/avatars/small/1358290528_128866_50-cent.jpeg'},
#    'thumb': {'bounding_box': {'height': 32, 'width': 32},
#     'url': 'https://s3.amazonaws.com/rapgenius/avatars/thumb/1358290528_128866_50-cent.jpeg'},
#    'tiny': {'bounding_box': {'height': 16, 'width': 16},
#     'url': 'https://s3.amazonaws.com/rapgenius/avatars/tiny/128866_50-cent.jpeg'}},
#   'current_user_metadata': {'interactions': {'following': False},
#    'permissions': []},
#   'header_image_url': 'https://s3.amazonaws.com/rapgenius/avatars/medium/1358290527_128866_50-cent.jpeg',
#   'human_readable_role_for_display': 'Verified Artist',
#   'id': 128866,
#   'iq': 2772,
#   'login': '50Cent',
#   'name': '50 Cent',
#   'role_for_display': 'verified_artist',
#   'url': 'http://genius.com/50Cent'}}

# %%
from gevent.queue import JoinableQueue
import os 
import msgpack
from datetime import datetime

q_artists = JoinableQueue()
q_songs = JoinableQueue()
q_serial = JoinableQueue()
    
def artist_worker():
    while True:
        artist_id, page_n = q_artists.get()
        
        try:
            song_page = api.get_artist_songs(artist_id, page_n)

            for song in song_page['songs']:
                q_songs.put(song['id'])
            
            next_page = song_page['next_page']
            if next_page:
                q_artists.put((artist_id, next_page))
        except Exception as e:
            print('fucked up grabbing artist songs')
            print(e)
        finally:
            q_artists.task_done()

def song_worker():
    while True:
        song_id = q_songs.get()
        
        try:
            song_details = api.get_song(song_id)
            gevent.sleep(0)
            song_lyrics = xpath_query_url(song_details['url'], '//lyrics//text()')
            gevent.sleep(0)
            song_lyrics_clean = [l.replace('\n','') for l in lyrics \
                                 if len(l.strip()) > 1 and 'googletag' not in l]
            song_details['lyrics'] = song_lyrics_clean
            q_serial.put(song_details)
        except Exception as e:
            print('fucked up grabbing song')
            print(e)
        finally:
            q_songs.task_done()

def serial_worker():
    while True:
        song = q_serial.get()        
        try:       
            artist = song['primary_artist']['url'].split('/')[-1]
            artist_path = 'lyrics/{}'.format(artist)
            
            if not os.path.isdir(artist_path):
                os.makedirs(artist_path)     
                
            filepath = '{}/{}'.format(artist_path, song['path'])
            
            with open(filepath, 'wb') as f:
                msgpack.pack(song, f)
        except Exception as e:
            print('fucked up serializing song')
            print(e)
        finally:
            q_serial.task_done()

for artist_id in artist_ids_stripped:
    q_artists.put((artist_id, 1))
    
artist_workers = []
for _ in range(50):
    artist_workers.append(gevent.spawn(artist_worker))
    
song_workers = []
for _ in range(50):
    song_workers.append(gevent.spawn(song_worker))
    
serial_workers = []
for _ in range(25):
    serial_workers.append(gevent.spawn(serial_worker))
t1 = datetime.now()
q_artists.join()
q_songs.join()
q_serial.join()
gevent.killall(artist_workers)
gevent.killall(song_workers)
gevent.killall(serial_workers)
print('Took {}'.format(datetime.now() - t1))
# Out:
# fucked up grabbing artist songs
# 'NoneType' object is not subscriptable

# %%
def consolidate_lyrics(q):
    '''Consolidates all of the lyric files by their respective
    primary artist.'''
    while True:
        artist = q.get()
        try:
            songs = {}
            artist_path = 'lyrics/{}'.format(artist)
            for song_name in os.listdir(artist_path):
                song_path = '{}/{}'.format(artist_path, song_name)
                with open(song_path, 'rb') as s_file:
                    song_details = msgpack.unpack(s_file)
                    songs[song_name] = song_details

            if not os.path.isdir('lyrics_consolidated'):
                os.makedirs('lyrics_consolidated')

            with open('lyrics_consolidated/{}.mpk'.format(artist), 'wb') as a_file:
                msgpack.pack(songs, a_file)
        except Exception as e:
            print(artist, artist_path, song_name, song_path)
        finally:
            q.task_done()

q_artists = JoinableQueue()
for artist in os.listdir('lyrics'):
    q_artists.put(artist)

consolidate_workers = []
for _ in range (10):
    work = gevent.spawn(consolidate_lyrics, q_artists)
    consolidate_workers.append(work)
    
q_artists.join()
gevent.killall(consolidate_workers)

# %%
for artist in os.listdir('lyrics'):
    file = os.listdir('lyrics/{}'.format())
